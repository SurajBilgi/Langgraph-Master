# %% [markdown]
# #### Faiss
# Facebook AI Similarity Search (Faiss) is a library for efficient similarity search and clustering of dense vectors. It contains algorithms that search in sets of vectors of any size, up to ones that possibly do not fit in RAM. It also contains supporting code for evaluation and parameter tuning.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

loader=TextLoader("suraj.txt")
documents=loader.load()
text_splitter=CharacterTextSplitter(chunk_size=500,chunk_overlap=30)
docs=text_splitter.split_documents(documents)
# Out:
# Created a chunk of size 576, which is longer than the specified 500
# Created a chunk of size 713, which is longer than the specified 500
# Created a chunk of size 873, which is longer than the specified 500
# Created a chunk of size 638, which is longer than the specified 500

# %%
docs
# Out:
# [Document(metadata={'source': 'suraj.txt'}, page_content='Suraj is a seasoned AI/ML Engineer with over four years of hands-on experience designing, developing, and deploying intelligent systems across a spectrum of industries, including healthcare, enterprise automation, and 3D environment reconstruction. With a strong foundation in both traditional machine learning and cutting-edge deep learning techniques, he has consistently delivered robust, scalable, and production-ready AI solutions that drive tangible business impact.'),
#  Document(metadata={'source': 'suraj.txt'}, page_content='He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'),
#  Document(metadata={'source': 'suraj.txt'}, page_content='Building on this foundation, Suraj joined iNeuron Intelligence, where he delved deeper into medical AI applications. He developed a CNN-based diagnostic model for diabetic retinopathy, achieving a 91% AUC score in clinical-grade image classification. Simultaneously, he led NLP-driven solutions to extract structured patient information from unstructured EHRs using spaCy, regex-based pipelines, and later transitioned into Large Language Models. He successfully integrated GPT-4 via LangChain for summarizing diagnostic reports, enhancing clinical decision-making across multiple departments. His solutions significantly improved data extraction, patient care workflows, and risk prediction in clinical settings.'),
#  Document(metadata={'source': 'suraj.txt'}, page_content='Currently, at Tracker Groups LLC, Suraj plays a pivotal role in pushing the frontiers of applied AI in 3D spatial understanding and advanced analytics. He engineered a 3D reconstruction pipeline using LiDAR data and Open3D, integrated with semantic segmentation, resulting in a 40% throughput gain in rendering environments for indoor spaces. His role extends into backend engineering and MLOps, having built and deployed secure FastAPI-based microservices integrated with AWS SQS, JWT authentication, and Dockerized workflows. His contributions include model dashboards using MLflow, object detection with CNNs, document classification using RNNs, and BERT/GPT-based NLP systems for sentiment and intent classification. Across these projects, he has repeatedly demonstrated a unique blend of deep technical skills, software engineering rigor, and product-centric thinking.'),
#  Document(metadata={'source': 'suraj.txt'}, page_content='Technically, Suraj is fluent in Python and adept with the ML/DL ecosystem, including PyTorch, TensorFlow, Keras, Scikit-learn, Hugging Face Transformers, and LangChain. His statistical modeling expertise spans hypothesis testing, predictive analytics, and unsupervised learning techniques. His ML infrastructure skills are equally strong—he’s well-versed in AWS (SageMaker, EC2, S3, Lambda, CloudWatch, ECS), GCP (Vertex AI), CI/CD pipelines, Docker, and Terraform. He also brings robust experience with databases like PostgreSQL, Redis, and Neo4j, and tools like Apache Airflow and MLflow for workflow automation and experiment tracking.'),
#  Document(metadata={'source': 'suraj.txt'}, page_content='Suraj holds a Master’s degree in Applied Artificial Intelligence from Stevens Institute of Technology. He is AWS Certified and has completed a specialization in Generative AI with LLMs. Passionate about solving complex problems with AI, his current focus lies in building intelligent systems that combine perception (vision), understanding (NLP/LLMs), and action (decision-making) to create transformative real-world solutions.')]

# %%
embeddings=OllamaEmbeddings(model="llama3.2")
db=FAISS.from_documents(docs,embeddings)
db
# Out:
# /var/folders/tf/f1jgzf2d0xzcc60pd4rv9f780000gn/T/ipykernel_56132/764663191.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings=OllamaEmbeddings(model="llama3.2")

# %%
### querying 
query="List the companies he worked on"
docs=db.similarity_search(query)
docs[0].page_content
# Out:
# 'He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'

# %% [markdown]
# #### As a Retriever
# We can also convert the vectorstore into a Retriever class. This allows us to easily use it in other LangChain methods, which largely work with retrievers

# %%
retriever=db.as_retriever()
docs=retriever.invoke(query)
docs[0].page_content
# Out:
# 'He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'

# %% [markdown]
# #### Similarity Search with score
# There are some FAISS specific methods. One of them is similarity_search_with_score, which allows you to return not only the documents but also the distance score of the query to them. The returned distance score is L2 distance. Therefore, a lower score is better.

# %%
docs_and_score=db.similarity_search_with_score(query)
docs_and_score
# Out:
# [(Document(id='dff8ab54-f7cc-487c-a92b-8b27ff030a20', metadata={'source': 'suraj.txt'}, page_content='He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'),
#   np.float32(7678.937)),
#  (Document(id='5aa2024a-96eb-44d7-9dee-e44f10222053', metadata={'source': 'suraj.txt'}, page_content='Suraj holds a Master’s degree in Applied Artificial Intelligence from Stevens Institute of Technology. He is AWS Certified and has completed a specialization in Generative AI with LLMs. Passionate about solving complex problems with AI, his current focus lies in building intelligent systems that combine perception (vision), understanding (NLP/LLMs), and action (decision-making) to create transformative real-world solutions.'),
#   np.float32(8222.84)),
#  (Document(id='b65be044-15cd-4011-9cdb-b41e21cb2823', metadata={'source': 'suraj.txt'}, page_content='Building on this foundation, Suraj joined iNeuron Intelligence, where he delved deeper into medical AI applications. He developed a CNN-based diagnostic model for diabetic retinopathy, achieving a 91% AUC score in clinical-grade image classification. Simultaneously, he led NLP-driven solutions to extract structured patient information from unstructured EHRs using spaCy, regex-based pipelines, and later transitioned into Large Language Models. He successfully integrated GPT-4 via LangChain for summarizing diagnostic reports, enhancing clinical decision-making across multiple departments. His solutions significantly improved data extraction, patient care workflows, and risk prediction in clinical settings.'),
#   np.float32(8439.863)),
#  (Document(id='65e29f7d-248e-43e0-a57b-8a96b3cb99b1', metadata={'source': 'suraj.txt'}, page_content='Currently, at Tracker Groups LLC, Suraj plays a pivotal role in pushing the frontiers of applied AI in 3D spatial understanding and advanced analytics. He engineered a 3D reconstruction pipeline using LiDAR data and Open3D, integrated with semantic segmentation, resulting in a 40% throughput gain in rendering environments for indoor spaces. His role extends into backend engineering and MLOps, having built and deployed secure FastAPI-based microservices integrated with AWS SQS, JWT authentication, and Dockerized workflows. His contributions include model dashboards using MLflow, object detection with CNNs, document classification using RNNs, and BERT/GPT-based NLP systems for sentiment and intent classification. Across these projects, he has repeatedly demonstrated a unique blend of deep technical skills, software engineering rigor, and product-centric thinking.'),
#   np.float32(8726.745))]

# %%
embedding_vector=embeddings.embed_query(query)
embedding_vector
# Out:
# [-1.3596292734146118,
#  -1.5510677099227905,
#  1.6135107278823853,
#  -1.2145380973815918,
#  0.22306373715400696,
#  -0.743732750415802,
#  0.4384339153766632,
#  0.17169876396656036,
#  0.46322980523109436,
#  0.39545387029647827,
#  0.7668346762657166,
#  -0.6951468586921692,
#  1.7802459001541138,
#  0.6512146592140198,
#  -0.06905478984117508,
#  0.23536764085292816,
#  0.11343193054199219,
#  -1.4829609394073486,
#  0.45334944128990173,
#  -0.5792098641395569,
#  -1.055586576461792,
#  -1.8453829288482666,
#  1.7883820533752441,
#  0.40555527806282043,
#  1.0911856889724731,
#  -1.1419998407363892,
#  2.2206826210021973,
#  -2.230595827102661,
#  1.9162901639938354,
#  0.3997955322265625,
#  0.32253432273864746,
#  1.7801663875579834,
#  0.5828211307525635,
#  0.4423215687274933,
#  -1.455322504043579,
#  0.7580912113189697,
#  0.7411032915115356,
#  1.2661795616149902,
#  -1.724794864654541,
#  -0.512087881565094,
#  -1.3300725221633911,
#  1.2593400478363037,
#  0.2418956309556961,
#  0.2187410593032837,
#  -1.7577353715896606,
#  -0.7099931836128235,
#  2.3856918811798096,
#  0.8976609110832214,
#  -0.3799765706062317,
#  -0.4509357511997223,
#  1.690359115600586,
#  0.21735753118991852,
#  0.8829756379127502,
#  1.0222351551055908,
#  -0.20491483807563782,
#  0.49612995982170105,
#  1.1099134683609009,
#  -1.1330342292785645,
#  0.4108884930610657,
#  0.4356217086315155,
#  0.12340497225522995,
#  -1.2590855360031128,
#  -0.6513339877128601,
#  -1.2638095617294312,
#  2.9747986793518066,
#  -3.5125153064727783,
#  0.1784188449382782,
#  -0.2776320278644562,
#  -0.548659086227417,
#  -0.2926400303840637,
#  0.07566801458597183,
#  0.08016816526651382,
#  0.3542230427265167,
#  -1.3910635709762573,
#  -1.102230191230774,
#  0.8087705969810486,
#  0.17415167391300201,
#  2.186037063598633,
#  -0.1861836016178131,
#  -0.026737317442893982,
#  0.8175264000892639,
#  -0.5265165567398071,
#  -1.0149332284927368,
#  2.1390740871429443,
#  -1.421828269958496,
#  -1.290658712387085,
#  1.8014200925827026,
#  0.5139786005020142,
#  -2.3990159034729004,
#  0.6553831696510315,
#  -0.21506832540035248,
#  0.39512646198272705,
#  0.8504075407981873,
#  2.7509994506835938,
#  1.7653379440307617,
#  1.2935417890548706,
#  -1.3021830320358276,
#  0.426300585269928,
#  1.1902979612350464,
#  -1.5624396800994873,
#  0.6702837347984314,
#  -1.6074039936065674,
#  0.7613822817802429,
#  1.6996856927871704,
#  -1.8562836647033691,
#  -0.1445596069097519,
#  2.290875196456909,
#  -0.5190666913986206,
#  -1.3226572275161743,
#  0.5617566704750061,
#  -0.6356518864631653,
#  0.778373122215271,
#  2.6367781162261963,
#  0.6037673354148865,
#  -1.9525007009506226,
#  1.5145299434661865,
#  -0.8439942598342896,
#  -0.880587637424469,
#  -0.8169653415679932,
#  -1.1139798164367676,
#  0.3115743398666382,
#  0.22993189096450806,
#  0.007375475484877825,
#  -0.07847064733505249,
#  -0.4812997281551361,
#  -0.8587820529937744,
#  -0.5470980405807495,
#  1.2719383239746094,
#  -1.3163927793502808,
#  1.0378168821334839,
#  0.04405179247260094,
#  ...]

# %%
docs_score=db.similarity_search_by_vector(embedding_vector)
docs_score
# Out:
# [Document(id='dff8ab54-f7cc-487c-a92b-8b27ff030a20', metadata={'source': 'suraj.txt'}, page_content='He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'),
#  Document(id='5aa2024a-96eb-44d7-9dee-e44f10222053', metadata={'source': 'suraj.txt'}, page_content='Suraj holds a Master’s degree in Applied Artificial Intelligence from Stevens Institute of Technology. He is AWS Certified and has completed a specialization in Generative AI with LLMs. Passionate about solving complex problems with AI, his current focus lies in building intelligent systems that combine perception (vision), understanding (NLP/LLMs), and action (decision-making) to create transformative real-world solutions.'),
#  Document(id='b65be044-15cd-4011-9cdb-b41e21cb2823', metadata={'source': 'suraj.txt'}, page_content='Building on this foundation, Suraj joined iNeuron Intelligence, where he delved deeper into medical AI applications. He developed a CNN-based diagnostic model for diabetic retinopathy, achieving a 91% AUC score in clinical-grade image classification. Simultaneously, he led NLP-driven solutions to extract structured patient information from unstructured EHRs using spaCy, regex-based pipelines, and later transitioned into Large Language Models. He successfully integrated GPT-4 via LangChain for summarizing diagnostic reports, enhancing clinical decision-making across multiple departments. His solutions significantly improved data extraction, patient care workflows, and risk prediction in clinical settings.'),
#  Document(id='65e29f7d-248e-43e0-a57b-8a96b3cb99b1', metadata={'source': 'suraj.txt'}, page_content='Currently, at Tracker Groups LLC, Suraj plays a pivotal role in pushing the frontiers of applied AI in 3D spatial understanding and advanced analytics. He engineered a 3D reconstruction pipeline using LiDAR data and Open3D, integrated with semantic segmentation, resulting in a 40% throughput gain in rendering environments for indoor spaces. His role extends into backend engineering and MLOps, having built and deployed secure FastAPI-based microservices integrated with AWS SQS, JWT authentication, and Dockerized workflows. His contributions include model dashboards using MLflow, object detection with CNNs, document classification using RNNs, and BERT/GPT-based NLP systems for sentiment and intent classification. Across these projects, he has repeatedly demonstrated a unique blend of deep technical skills, software engineering rigor, and product-centric thinking.')]

# %%
### Saving And Loading
db.save_local("faiss_index")

# %%
new_db=FAISS.load_local("faiss_index",embeddings,allow_dangerous_deserialization=True)
docs=new_db.similarity_search(query)

# %%
docs
# Out:
# [Document(id='dff8ab54-f7cc-487c-a92b-8b27ff030a20', metadata={'source': 'suraj.txt'}, page_content='He began his career at Resolute AI Software, where he architected real-time AI services using OpenCV and LSTMs to detect anomalous user behavior in video feeds—drastically reducing manual monitoring workloads. At the same time, he spearheaded initiatives to modernize ML workflows by migrating legacy models to AWS SageMaker, implementing RESTful model endpoints using API Gateway and Lambda, and leveraging ensemble learning for predictive analytics in sales and customer churn domains. His work laid a strong foundation in MLOps, cloud-native deployment, and operational AI.'),
#  Document(id='5aa2024a-96eb-44d7-9dee-e44f10222053', metadata={'source': 'suraj.txt'}, page_content='Suraj holds a Master’s degree in Applied Artificial Intelligence from Stevens Institute of Technology. He is AWS Certified and has completed a specialization in Generative AI with LLMs. Passionate about solving complex problems with AI, his current focus lies in building intelligent systems that combine perception (vision), understanding (NLP/LLMs), and action (decision-making) to create transformative real-world solutions.'),
#  Document(id='b65be044-15cd-4011-9cdb-b41e21cb2823', metadata={'source': 'suraj.txt'}, page_content='Building on this foundation, Suraj joined iNeuron Intelligence, where he delved deeper into medical AI applications. He developed a CNN-based diagnostic model for diabetic retinopathy, achieving a 91% AUC score in clinical-grade image classification. Simultaneously, he led NLP-driven solutions to extract structured patient information from unstructured EHRs using spaCy, regex-based pipelines, and later transitioned into Large Language Models. He successfully integrated GPT-4 via LangChain for summarizing diagnostic reports, enhancing clinical decision-making across multiple departments. His solutions significantly improved data extraction, patient care workflows, and risk prediction in clinical settings.'),
#  Document(id='65e29f7d-248e-43e0-a57b-8a96b3cb99b1', metadata={'source': 'suraj.txt'}, page_content='Currently, at Tracker Groups LLC, Suraj plays a pivotal role in pushing the frontiers of applied AI in 3D spatial understanding and advanced analytics. He engineered a 3D reconstruction pipeline using LiDAR data and Open3D, integrated with semantic segmentation, resulting in a 40% throughput gain in rendering environments for indoor spaces. His role extends into backend engineering and MLOps, having built and deployed secure FastAPI-based microservices integrated with AWS SQS, JWT authentication, and Dockerized workflows. His contributions include model dashboards using MLflow, object detection with CNNs, document classification using RNNs, and BERT/GPT-based NLP systems for sentiment and intent classification. Across these projects, he has repeatedly demonstrated a unique blend of deep technical skills, software engineering rigor, and product-centric thinking.')]
